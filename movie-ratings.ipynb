# %%
import pandas as pd

# %%
movie = pd.read_csv(r'E:\nit\19\Movie-Rating.csv')
movie
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movie.shape
# Out:
# (559, 6)

# %%
movie.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movie.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.columns = ['Movie', 'Genre','CriticRatings','AudienceRatings' , 'BudgetMillions','Year']
movie.head()
# Out:
#                    Movie      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Movie            559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movie['AudienceRatings']
# Out:
# 0      81
# 1      44
# 2      52
# 3      84
# 4      70
#        ..
# 554    36
# 555    52
# 556    73
# 557    87
# 558    42
# Name: AudienceRatings, Length: 559, dtype: int64

# %%
movie.Movie = movie.Movie.astype('category')
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Movie            559 non-null    category
#  1   Genre            559 non-null    object
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movie.Genre = movie.Genre.astype('category')
movie.Year = movie.Year.astype('category')
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Movie            559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movie.describe()
# Out:
#        CriticRatings  AudienceRatings  BudgetMillions
# count     559.000000       559.000000      559.000000
# mean       47.309481        58.744186       50.236136
# std        26.413091        16.826887       48.731817
# min         0.000000         0.000000        0.000000
# 25%        25.000000        47.000000       20.000000
# 50%        46.000000        58.000000       35.000000
# 75%        70.000000        72.000000       65.000000
# max        97.000000        96.000000      300.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data = movie, x = 'CriticRatings', y = 'AudienceRatings', kind = "hex")

# %%
m1 = sns.distplot(movie.CriticRatings)

# %%
m2 = sns.distplot(movie.AudienceRatings)

# %%
m1 = sns.displot(movie.CriticRatings)

# %%
sns.set_style('whitegrid')           ## addimng a grid at backgorund

# %%
m2 = sns.distplot(movie.AudienceRatings, bins = 10)

# %%
sns.set_style('white')
m3 = sns.distplot(movie.AudienceRatings, bins= 10)

# %%
m3 = plt.hist(movie.AudienceRatings, bins= 100)              


## OUTLIER AT ZERO

# %%
m3 = plt.hist(movie.CriticRatings, bins= 20)

# %%
plt.hist(movie.BudgetMillions)
plt.show()

# %%
plt.hist(movie[movie.Genre == 'Drama'].BudgetMillions)
# Out:
# (array([25., 40., 18.,  8.,  6.,  2.,  1.,  0.,  0.,  1.]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.]),
#  <BarContainer object of 10 artists>)

# %%
movie.head()
# Out:
#                    Movie      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
sns.set_style('darkgrid')
plt.hist(movie[movie.Genre == 'Drama'].BudgetMillions , bins =20)
plt.hist(movie[movie.Genre == 'Thriller'].BudgetMillions , bins =20)
plt.hist(movie[movie.Genre == 'Comedy'].BudgetMillions , bins =20)
plt.hist(movie[movie.Genre == 'Action'].BudgetMillions , bins =20)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist([movie[movie.Genre == 'Drama'].BudgetMillions , 
         movie[movie.Genre == 'Comedy'].BudgetMillions ,
         movie[movie.Genre == 'Thriller'].BudgetMillions ,
         movie[movie.Genre == 'Action'].BudgetMillions] ,
        bins =20 , stacked = True)
plt.show()

# %%
for gen in movie.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
l1 = sns.lmplot(data = movie,x ="AudienceRatings",y="CriticRatings",\
               fit_reg=False , hue = 'Genre')

# %%
l2 = sns.lmplot(data = movie,x ="AudienceRatings",y="CriticRatings",
               fit_reg=True , hue = 'Genre')

# %%
L3 = sns.lmplot(data= movie , x = "AudienceRatings", y= "CriticRatings",
               fit_reg = True , hue='Genre', aspect=1)

# %%
sns.set_style('darkgrid')
l3 = sns.kdeplot(data=movie,x='CriticRatings',y='AudienceRatings')

# %%
sns.set_style('darkgrid')
k1 = sns.kdeplot(data = movie , x = 'CriticRatings', y='AudienceRatings', fill = True , color = 'Green' )

# %%
k2 = sns.kdeplot(data = movie , x = 'BudgetMillions', y = 'AudienceRatings' , shade_lowest = True , cmap = 'Greens_r')

# %%
k2 = sns.kdeplot(data = movie , x = 'BudgetMillions', y = 'AudienceRatings' , fill = True )

# %%
k2 = sns.kdeplot(data = movie , x = 'BudgetMillions', y = 'CriticRatings')

# %%
k2 = sns.kdeplot(data = movie , x = 'BudgetMillions', y = 'AudienceRatings' , fill= True , cmap = 'Greens_r')

# %%
f , axes = plt.subplots(1,3, figsize =(12,6))

k1 = sns.kdeplot(data = movie , x = 'CriticRatings', y='AudienceRatings', fill = True , color = 'Green' , ax = axes[0])
k2 = sns.kdeplot(data = movie , x = 'BudgetMillions', y = 'AudienceRatings' , fill= True , cmap = 'Greens_r' , ax = axes[1])
k3 = sns.kdeplot(data = movie , x = 'BudgetMillions', y = 'CriticRatings' , fill= True , cmap = 'Greens_r' , ax = axes[2])

# %%
l4 = sns.boxplot(data = movie , x = "Genre" , y = "AudienceRatings" )

# %%
l4 = sns.boxplot(data = movie , x = "Genre" , y = "CriticRatings" )

# %%
sns.boxplot(data = movie[movie.Genre == "Action"] , x = "Year" , y = "CriticRatings")
# Out:
# <Axes: xlabel='Year', ylabel='CriticRatings'>

# %%
l4 = sns.violinplot(data = movie , x = "Genre" , y = "CriticRatings" )

# %%
z = sns.violinplot(data = movie[movie.Genre == "Action"] , x = "Year" , y = "CriticRatings")

# %%
plt.scatter(movie.AudienceRatings , movie.CriticRatings)

# %%
g = sns.FacetGrid(data = movie , row = "Genre" , col = "Year" , hue = "Genre")

# %%
g = sns.FacetGrid(data = movie , row = "Genre" , col = "Year" , hue = "Genre")
g = g.map(plt.scatter , "AudienceRatings","CriticRatings")

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots(2,2 , figsize=(12,12))
n1 = sns.kdeplot(data = movie , x = "BudgetMillions" , y = "CriticRatings" , ax = axes[0,0] , fill = True)
k2 = sns.kdeplot(data = movie , x = "BudgetMillions" , y = "AudienceRatings" , ax = axes[0,1])

n1.set(xlim=(-100,300))
k2.set(xlim=(-100,300))

z = sns.violinplot(data=movie[movie.Genre == 'Drama'], x = "Year" , y = "CriticRatings" , ax = axes[1,0] , palette = 'muted' )

k4 = sns.kdeplot(data = movie , x = "CriticRatings" , y = "AudienceRatings" ,shade = True,cmap = 'Reds', ax = axes[1,1])

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))


k1 = sns.kdeplot(x=movie.BudgetMillions,y=movie.AudienceRatings, \
                 shade = True,cmap = 'inferno', \
                 ax = axes[0,0])
k1b = sns.kdeplot(x=movie.BudgetMillions, y=movie.AudienceRatings, \
                 cmap = 'cool',ax = axes[0,0])


k2 = sns.kdeplot(x=movie.BudgetMillions,y=movie.CriticRatings,\
                 shade=True, shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(x=movie.BudgetMillions,y=movie.CriticRatings,\
                  cmap = 'cool', ax = axes[0,1])

z = sns.violinplot(data=movie[movie.Genre=='Drama'], \
                   x='Year', y = 'CriticRatings', ax=axes[1,0] ,  palette = 'muted')

k4 = sns.kdeplot(x=movie.CriticRatings,y=movie.AudienceRatings, \
                 shade = True,shade_lowest=False,cmap='Blues_r', \
                 ax=axes[1,1])
k4b = sns.kdeplot(x=movie.CriticRatings, y=movie.AudienceRatings, \
                  cmap='gist_gray_r',ax = axes[1,1])


k1.set(xlim=(-100,300))
k2.set(xlim=(-100,300))

plt.show()
